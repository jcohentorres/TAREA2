# %% [markdown]
# # **IMPORTACIÓN**

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import random
np.random.seed(100)

# %% [markdown]
# # **IMPORTAR BASE DE DATOS**

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-766f5e14-7943-41e0-80b9-8fd2cb81904b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-766f5e14-7943-41e0-80b9-8fd2cb81904b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving dataset_Facebook.csv to dataset_Facebook.csv

# %% [markdown]
# # **MOSTRAR LA BASE DE DATOS**

# %%
data=pd.read_csv("dataset_Facebook.csv",delimiter=";")
data
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %% [markdown]
# # **MOSTRAR LOS TIPOS DE DATOS** **(NUMÉRICOS U OBJETOS)**

# %%
data.dtypes
# Out:
# Page total likes                                                         int64
# Type                                                                    object
# Category                                                                 int64
# Post Month                                                               int64
# Post Weekday                                                             int64
# Post Hour                                                                int64
# Paid                                                                   float64
# Lifetime Post Total Reach                                                int64
# Lifetime Post Total Impressions                                          int64
# Lifetime Engaged Users                                                   int64
# Lifetime Post Consumers                                                  int64
# Lifetime Post Consumptions                                               int64
# ...

# %%
data1=data.select_dtypes(include='int64')

# %%
data1.dtypes
# Out:
# Page total likes                                                       int64
# Category                                                               int64
# Post Month                                                             int64
# Post Weekday                                                           int64
# Post Hour                                                              int64
# Lifetime Post Total Reach                                              int64
# Lifetime Post Total Impressions                                        int64
# Lifetime Engaged Users                                                 int64
# Lifetime Post Consumers                                                int64
# Lifetime Post Consumptions                                             int64
# Lifetime Post Impressions by people who have liked your Page           int64
# Lifetime Post reach by people who like your Page                       int64
# ...

# %% [markdown]
# # **¿CUANTAS INSTANCIAS O FILAS TENGO?**

# %%
print("tengo n=",len(data),"instancias")
# Out:
# tengo n= 500 instancias

# %% [markdown]
# # **¿CUANTOS ATRIBUTOS O COLUMNAS TENGO?**

# %%
print("tengo n=",len(data.columns),"atributos")
# Out:
# tengo n= 19 atributos

# %% [markdown]
# # **¿CUANTOS NaN O PERDIDOS HAY?**

# %%
len(data[data.isna().any(axis=1)])
# Out:
# 5

# %%
data[data.isna().any(axis=1)]
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 111            136736  Photo         1          10             6          8
# 120            136393  Photo         1          10             7          9
# 124            136393  Photo         1          10             7          6
# 164            135428  Photo         1           9             5         10
# 499             81370  Photo         2           1             4          4
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 111   0.0                       1261                             2158
# 120   0.0                        584                             1029
# 124   0.0                        677                             1285
# 164   0.0                       1060                             2004
# 499   NaN                       4188                             7292
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %% [markdown]
# # **MOSTRAR DATOS PERDIDOS**

# %%
perdido=data[data.isna().any(axis=1)] #encontrar datos perdidos
print("tengo n=",len(perdido),"perdidos")
# Out:
# tengo n= 5 perdidos

# %% [markdown]
# # **EMBASURAR LA BASE DE DATOS**

# %%
#copias de la data
data2=data1.copy()
data3=data1.copy()

# %%
length = len(data2)
for i in data2.columns[:-3]:
    num = int(np.random.randint(0,5)/100*length)
    idx_replace = np.random.randint(0, length-1, num)
    data2.loc[idx_replace, i] = np.nan

# %%
data2
# Out:
#      Page total likes  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441.0       2.0        12.0           4.0        3.0
# 1            139441.0       2.0        12.0           3.0       10.0
# 2            139441.0       3.0        12.0           NaN        3.0
# 3            139441.0       2.0        12.0           2.0       10.0
# 4            139441.0       2.0        12.0           2.0        3.0
# ..                ...       ...         ...           ...        ...
# 495           85093.0       3.0         1.0           7.0        2.0
# 496           81370.0       2.0         1.0           5.0        8.0
# 497           81370.0       1.0         1.0           5.0        2.0
# 498           81370.0       3.0         1.0           4.0       11.0
# 499           81370.0       2.0         1.0           4.0        4.0
#
#      Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0                       2752.0                           5091.0
# ...

# %%
length = len(data3)
for i in data3.columns[:-3]:
    num = int(np.random.randint(0,5)/100*length)
    idx_replace = np.random.randint(0, length-1, num)
    data3.loc[idx_replace, i] = np.nan

# %%
data3
# Out:
#      Page total likes  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441.0       2.0        12.0           4.0        3.0
# 1            139441.0       2.0        12.0           3.0       10.0
# 2            139441.0       3.0        12.0           3.0        3.0
# 3            139441.0       2.0        12.0           2.0       10.0
# 4            139441.0       2.0        12.0           2.0        3.0
# ..                ...       ...         ...           ...        ...
# 495           85093.0       3.0         1.0           7.0        2.0
# 496           81370.0       2.0         1.0           5.0        8.0
# 497               NaN       1.0         1.0           5.0        2.0
# 498               NaN       3.0         1.0           4.0       11.0
# 499           81370.0       2.0         1.0           4.0        4.0
#
#      Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0                       2752.0                           5091.0
# ...

# %% [markdown]
# # **PERDIDOS EN LA NUEVA BASE DE DATOS EMBASURADA**

# %%
perdido=data2[data2.isna().any(axis=1)] #encontrar datos perdidos
print("tengo n=",len(perdido),"perdidos")
# Out:
# tengo n= 135 perdidos

# %% [markdown]
# # **OTRA FORMA DE MOSTRAR LOS PERDIDOS**

# %%
# OTRA FORMA DE MOSTRAR LOS PERDIDOS (Hay una forma más sencilla aún...)
data2.isnull().sum()
# Out:
# Page total likes                                                       20
# Category                                                               10
# Post Month                                                             20
# Post Weekday                                                           20
# Post Hour                                                              10
# Lifetime Post Total Reach                                               5
# Lifetime Post Total Impressions                                        10
# Lifetime Engaged Users                                                  5
# Lifetime Post Consumers                                                 5
# Lifetime Post Consumptions                                             15
# Lifetime Post Impressions by people who have liked your Page           14
# Lifetime Post reach by people who like your Page                       15
# Lifetime People who have liked your Page and engaged with your post     0
# ...

# %% [markdown]
# # **OTRA FORMA DE MOSTRAR LOS PERDIDOS ( PORCENTAJE)**

# %%
# Hay una forma más sencilla aún (porcentaje)
data2.isnull().sum()/len(data2)*100
# Out:
# Page total likes                                                       4.0
# Category                                                               2.0
# Post Month                                                             4.0
# Post Weekday                                                           4.0
# Post Hour                                                              2.0
# Lifetime Post Total Reach                                              1.0
# Lifetime Post Total Impressions                                        2.0
# Lifetime Engaged Users                                                 1.0
# Lifetime Post Consumers                                                1.0
# Lifetime Post Consumptions                                             3.0
# Lifetime Post Impressions by people who have liked your Page           2.8
# Lifetime Post reach by people who like your Page                       3.0
# ...

# %% [markdown]
# # **CREANDO FUNCIONES PARA IMPUTAR**

# %%
# Podemos crear un par de funciones para imputar

def impute_nan_meanmedian(df, variable, value):
    if value=="median":
        val=df[variable].median()
    if value=="mean":
        val=df[variable].mean()
    df[variable+"_"+value]=df[variable].fillna(val)
    return df
import random
def rand_float_range(start, end):
    return random.random() * (end - start) + start

def impute_nan_random(df, variable, value=-9):
    if value!=-9:
        df[variable+"_random_fixed"]=df[variable].fillna(value)
    else:
        start,end=df[variable].min(),df[variable].max()
        df[variable+"_random"]=df[variable].fillna(rand_float_range(start,end))
    return df

# %% [markdown]
# # **IMPUTAR NAN RANDOM**

# %%
impute_nan_random(data2,"Post Weekday",-9)
# Out:
#      Page total likes  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441.0       2.0        12.0           4.0        3.0
# 1            139441.0       2.0        12.0           3.0       10.0
# 2            139441.0       3.0        12.0           NaN        3.0
# 3            139441.0       2.0        12.0           2.0       10.0
# 4            139441.0       2.0        12.0           2.0        3.0
# ..                ...       ...         ...           ...        ...
# 495           85093.0       3.0         1.0           7.0        2.0
# 496           81370.0       2.0         1.0           5.0        8.0
# 497           81370.0       1.0         1.0           5.0        2.0
# 498           81370.0       3.0         1.0           4.0       11.0
# 499           81370.0       2.0         1.0           4.0        4.0
#
#      Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0                       2752.0                           5091.0
# ...

# %% [markdown]
# # **IMPUTAR MEDIANA**

# %%
impute_nan_meanmedian(data2,"Post Weekday","median")
# Out:
#      Page total likes  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441.0       2.0        12.0           4.0        3.0
# 1            139441.0       2.0        12.0           3.0       10.0
# 2            139441.0       3.0        12.0           NaN        3.0
# 3            139441.0       2.0        12.0           2.0       10.0
# 4            139441.0       2.0        12.0           2.0        3.0
# ..                ...       ...         ...           ...        ...
# 495           85093.0       3.0         1.0           7.0        2.0
# 496           81370.0       2.0         1.0           5.0        8.0
# 497           81370.0       1.0         1.0           5.0        2.0
# 498           81370.0       3.0         1.0           4.0       11.0
# 499           81370.0       2.0         1.0           4.0        4.0
#
#      Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0                       2752.0                           5091.0
# ...

# %% [markdown]
# # **IMPUTAR MEDIA**

# %%
impute_nan_meanmedian(data2,"Post Weekday","mean")
# Out:
#      Page total likes  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441.0       2.0        12.0           4.0        3.0
# 1            139441.0       2.0        12.0           3.0       10.0
# 2            139441.0       3.0        12.0           NaN        3.0
# 3            139441.0       2.0        12.0           2.0       10.0
# 4            139441.0       2.0        12.0           2.0        3.0
# ..                ...       ...         ...           ...        ...
# 495           85093.0       3.0         1.0           7.0        2.0
# 496           81370.0       2.0         1.0           5.0        8.0
# 497           81370.0       1.0         1.0           5.0        2.0
# 498           81370.0       3.0         1.0           4.0       11.0
# 499           81370.0       2.0         1.0           4.0        4.0
#
#      Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0                       2752.0                           5091.0
# ...

# %% [markdown]
# # **USANDO KNN**

# %%
from sklearn.impute import KNNImputer
# define imputer
imputer = KNNImputer(n_neighbors=5, weights='uniform', metric='nan_euclidean')
# fit on the dataset
imputer.fit(data3)
# transform the dataset
Xtrans = imputer.transform(data3)

# %%
Xtrans
# Out:
# array([[1.394410e+05, 2.000000e+00, 1.200000e+01, ..., 1.190000e+02,
#         4.000000e+00, 1.000000e+02],
#        [1.394410e+05, 2.000000e+00, 1.200000e+01, ..., 1.108000e+03,
#         5.000000e+00, 1.640000e+02],
#        [1.394410e+05, 3.000000e+00, 1.200000e+01, ..., 1.320000e+02,
#         0.000000e+00, 8.000000e+01],
#        ...,
#        [1.255704e+05, 1.000000e+00, 1.000000e+00, ..., 3.630000e+02,
#         4.000000e+00, 1.150000e+02],
#        [1.302354e+05, 3.000000e+00, 1.000000e+00, ..., 3.700000e+02,
#         7.000000e+00, 1.360000e+02],
#        [8.137000e+04, 2.000000e+00, 1.000000e+00, ..., 3.160000e+02,
#         0.000000e+00, 1.190000e+02]])

# %%
Xtrans=pd.DataFrame(Xtrans,columns=data3.columns)

# %%
Xtrans
# Out:
#      Page total likes  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441.0       2.0        12.0           4.0        3.0
# 1            139441.0       2.0        12.0           3.0       10.0
# 2            139441.0       3.0        12.0           3.0        3.0
# 3            139441.0       2.0        12.0           2.0       10.0
# 4            139441.0       2.0        12.0           2.0        3.0
# ..                ...       ...         ...           ...        ...
# 495           85093.0       3.0         1.0           7.0        2.0
# 496           81370.0       2.0         1.0           5.0        8.0
# 497          125570.4       1.0         1.0           5.0        2.0
# 498          130235.4       3.0         1.0           4.0       11.0
# 499           81370.0       2.0         1.0           4.0        4.0
#
#      Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0                       2752.0                           5091.0
# ...

# %%
data2.isnull().sum()/len(data2)*100
# Out:
# Page total likes                                                       4.0
# Category                                                               2.0
# Post Month                                                             4.0
# Post Weekday                                                           4.0
# Post Hour                                                              2.0
# Lifetime Post Total Reach                                              1.0
# Lifetime Post Total Impressions                                        2.0
# Lifetime Engaged Users                                                 1.0
# Lifetime Post Consumers                                                1.0
# Lifetime Post Consumptions                                             3.0
# Lifetime Post Impressions by people who have liked your Page           2.8
# Lifetime Post reach by people who like your Page                       3.0
# ...

# %% [markdown]
# # **HISTOGRAMA**

# %%
plt.figure(figsize=(10,8))
plt.hist(data2["Post Weekday"],label="Original sin B",color="r",histtype="step",bins=20,lw=5)
plt.hist(data2["Post Weekday_random"],label="Original con B",color="orange",histtype="step",bins=20,lw=1)
plt.hist(data2["Post Weekday_median"],label="Mediana",color="b",histtype="step",bins=20,lw=3)
plt.hist(data2["Post Weekday_mean"],label="Mean",color="k",histtype="step",bins=20,lw=1)
plt.hist(Xtrans["Post Weekday"],label="KNN",color="g",histtype="step",bins=20,lw=1)
plt.legend()
plt.show()

# %% [markdown]
# El KNN seria la mejor opcion con respecto a las otras medidas puesto que el error esta mas cercano con respecto a la data original
